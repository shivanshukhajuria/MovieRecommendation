# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
col_name=['user_id','item_id','rating','timestamp']
df=pd.read_csv('moviedataset.csv',sep='\t',names=col_name)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
m_titles=pd.read_csv('u.item',sep='\|',header=None)

# %%
m_titles=m_titles[[0,1]]

# %%
m_titles
# Out:
#          0                                          1
# 0        1                           Toy Story (1995)
# 1        2                           GoldenEye (1995)
# 2        3                          Four Rooms (1995)
# 3        4                          Get Shorty (1995)
# 4        5                             Copycat (1995)
# ...    ...                                        ...
# 1677  1678                          Mat' i syn (1997)
# 1678  1679                           B. Monkey (1998)
# 1679  1680                       Sliding Doors (1998)
# 1680  1681                        You So Crazy (1994)
# 1681  1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
m_titles.columns=['item_id','title']

# %%
m_titles
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
df=pd.merge(df,m_titles,on='item_id')

# %%
df
# Out:
#        user_id  item_id  rating  timestamp  \
# 0          196      242       3  881250949
# 1           63      242       3  875747190
# 2          226      242       5  883888671
# 3          154      242       3  879138235
# 4          306      242       5  876503793
# ...        ...      ...     ...        ...
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 0                                           Kolya (1996)
# 1                                           Kolya (1996)
# 2                                           Kolya (1996)
# 3                                           Kolya (1996)
# 4                                           Kolya (1996)
# ...                                                  ...
# ...

# %%
import  matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
a=df.groupby('title')

# %%
a.mean()['rating'].sort_values(ascending=False)
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Prefontaine (1997)                              5.0
# Santa with Muscles (1996)                       5.0
# Star Kid (1997)                                 5.0
# Someone Else's America (1995)                   5.0
#                                                ...
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# JLG/JLG - autoportrait de d�cembre (1994)       1.0
# Daens (1992)                                    1.0
# Butterfly Kiss (1995)                           1.0
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# Name: rating, Length: 1664, dtype: float64

# %%
b=df.groupby('title').count()

# %%
b['rating'].sort_values(ascending=False)
# Out:
# title
# Star Wars (1977)                              583
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Man from Down Under, The (1943)                 1
# Marlene Dietrich: Shadow and Light (1996)       1
# Mat' i syn (1997)                               1
# Mille bolle blu (1993)                          1
# � k�ldum klaka (Cold Fever) (1994)              1
# Name: rating, Length: 1664, dtype: int64

# %%
ratings=pd.DataFrame(df.groupby('title').mean()['rating'])

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['Number of Ratings']=pd.DataFrame(df.groupby('title').count()["rating"])

# %%
rating.sort_values(by='rating',ascending=False)
# Out:
#                                               rating  Number of Ratings
# title
# They Made Me a Criminal (1939)                   5.0                  1
# Marlene Dietrich: Shadow and Light (1996)        5.0                  1
# Saint of Fort Washington, The (1993)             5.0                  2
# Someone Else's America (1995)                    5.0                  1
# Star Kid (1997)                                  5.0                  3
# ...                                              ...                ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0                  1
# King of New York (1990)                          1.0                  1
# Touki Bouki (Journey of the Hyena) (1973)        1.0                  1
# Bloody Child, The (1996)                         1.0                  1
# Crude Oasis, The (1995)                          1.0                  1
#
# [1664 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))

# %%
plt.hist(ratings['Number of Ratings'],bins=70)
plt.show()
plt.hist(ratings['rating'],bins=70)
# Out:
# (array([ 69.,   0.,   1.,   0.,   2.,   4.,   0.,   1.,  11.,   0.,   4.,
#           7.,   4.,   3.,   9.,   7.,   6.,  52.,   3.,   7.,  19.,  26.,
#          15.,  17.,  34.,  20.,  45.,  21.,  27.,  43.,  45.,  38.,  36.,
#          32.,  12., 127.,  40.,  63.,  46.,  45.,  57.,  32.,  53.,  59.,
#          42.,  49.,  52.,  36.,  45.,  45.,  35.,  35.,  64.,  24.,  27.,
#          14.,  15.,  11.,   5.,   2.,   5.,   5.,   0.,   1.,   0.,   0.,
#           0.,   0.,   0.,  10.]),
#  array([1.        , 1.05714286, 1.11428571, 1.17142857, 1.22857143,
#         1.28571429, 1.34285714, 1.4       , 1.45714286, 1.51428571,
#         1.57142857, 1.62857143, 1.68571429, 1.74285714, 1.8       ,
#         1.85714286, 1.91428571, 1.97142857, 2.02857143, 2.08571429,
#         2.14285714, 2.2       , 2.25714286, 2.31428571, 2.37142857,
#         2.42857143, 2.48571429, 2.54285714, 2.6       , 2.65714286,
#         2.71428571, 2.77142857, 2.82857143, 2.88571429, 2.94285714,
# ...

# %%
sns.jointplot(x='rating',y='Number of Ratings',data=ratings,alpha=0.5)

# %%
moviemat=df.pivot_table(index='user_id',columns='title',values='rating')
moviemat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
starwars_user_ratings=moviemat['Star Wars (1977)']

# %%
starwars_user_ratings
# Out:
# user_id
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
# 5      4.0
#       ...
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 943, dtype: float64

# %% [markdown]
# moviemat.corrwith(starwars_user_ratings)

# %%
moviemat.corrwith(starwars_user_ratings)
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# � k�ldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
similar_to_starwars=moviemat.corrwith(starwars_user_ratings)

# %%
# !pip install jupyter-tabnine
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/prabhjotsinghsodhi/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !jupyter nbextension install --py jupyter_tabnine
# Out:
# Installing /Users/prabhjotsinghsodhi/opt/anaconda3/lib/python3.8/site-packages/jupyter_tabnine/static -> jupyter_tabnine
# Up to date: /usr/local/share/jupyter/nbextensions/jupyter_tabnine/tabnine.yaml
# Up to date: /usr/local/share/jupyter/nbextensions/jupyter_tabnine/main.css
# Up to date: /usr/local/share/jupyter/nbextensions/jupyter_tabnine/README.md
# Up to date: /usr/local/share/jupyter/nbextensions/jupyter_tabnine/main.js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable jupyter_tabnine --py

# %%
# !jupyter nbextension enable --py jupyter_tabnine
# Out:
# Enabling notebook extension jupyter_tabnine/main...
#       - Validating: OK

# %%
# !jupyter serverextension enable --py jupyter_tabnine
# Out:
# Enabling: jupyter_tabnine
# - Writing config: /Users/prabhjotsinghsodhi/.jupyter
#     - Validating...
#       jupyter_tabnine  OK

# %%
corr_starwars=pd.DataFrame(similar_to_starwars,columns=['correlation'])

# %%
corr_starwars
# Out:
#                                        correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
# � k�ldum klaka (Cold Fever) (1994)             NaN
#
# [1664 rows x 1 columns]

# %%
corr_starwars.sort_values('correlation',ascending=False)
# Out:
#                                          correlation
# title
# Hollow Reed (1996)                               1.0
# Commandments (1997)                              1.0
# Cosi (1996)                                      1.0
# No Escape (1994)                                 1.0
# Stripes (1981)                                   1.0
# ...                                              ...
# Wonderland (1997)                                NaN
# Wooden Man's Bride, The (Wu Kui) (1994)          NaN
# Yankee Zulu (1994)                               NaN
# You So Crazy (1994)                              NaN
# � k�ldum klaka (Cold Fever) (1994)               NaN
#
# [1664 rows x 1 columns]

# %%
corr_starwars.dropna(inplace=True)

# %%
corr_starwars
# Out:
#                                        correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns (1988)                         0.186377
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
#
# [1410 rows x 1 columns]

# %%
corr_starwars.head()
# Out:
#                            correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_starwars.sort_values('correlation',ascending=False)
# Out:
#                                         correlation
# title
# Hollow Reed (1996)                              1.0
# Commandments (1997)                             1.0
# Cosi (1996)                                     1.0
# No Escape (1994)                                1.0
# Stripes (1981)                                  1.0
# ...                                             ...
# Roseanna's Grave (For Roseanna) (1997)         -1.0
# For Ever Mozart (1996)                         -1.0
# American Dream (1990)                          -1.0
# Frankie Starlight (1995)                       -1.0
# Fille seule, La (A Single Girl) (1995)         -1.0
#
# [1410 rows x 1 columns]

# %%
ratings['Number of Ratings']
corr_starwars=corr_starwars.join(ratings['Number of Ratings'])

# %%
corr_starwars
# Out:
#                                        correlation  Number of Ratings
# title
# 'Til There Was You (1997)                 0.872872                  9
# 1-900 (1994)                             -0.645497                  5
# 101 Dalmatians (1996)                     0.211132                109
# 12 Angry Men (1957)                       0.184289                125
# 187 (1997)                                0.027398                 41
# ...                                            ...                ...
# Young Guns (1988)                         0.186377                101
# Young Guns II (1990)                      0.228615                 44
# Young Poisoner's Handbook, The (1995)    -0.007374                 41
# Zeus and Roxanne (1997)                   0.818182                  6
# unknown                                   0.723123                  9
#
# [1410 rows x 2 columns]

# %%
corr_starwars[corr_starwars['Number of Ratings']>100].sort_values('correlation',ascending=False)
# Out:
#                                                     correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.747981
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
# ...                                                         ...
# Edge, The (1997)                                      -0.127167
# As Good As It Gets (1997)                             -0.130466
# Crash (1996)                                          -0.148507
# G.I. Jane (1997)                                      -0.176734
# First Wives Club, The (1996)                          -0.194496
#
#                                                     Number of Ratings
# title
# Star Wars (1977)                                                  583
# ...

# %%
# Out:
#                                         correlation  Number of Ratings
# title
# Hollow Reed (1996)                              1.0                  6
# Commandments (1997)                             1.0                  3
# Cosi (1996)                                     1.0                  4
# No Escape (1994)                                1.0                  5
# Stripes (1981)                                  1.0                  5
# ...                                             ...                ...
# Roseanna's Grave (For Roseanna) (1997)         -1.0                  5
# For Ever Mozart (1996)                         -1.0                  3
# American Dream (1990)                          -1.0                  2
# Frankie Starlight (1995)                       -1.0                  4
# Fille seule, La (A Single Girl) (1995)         -1.0                  4
#
# [1410 rows x 2 columns]

# %%
def predict_movies(movie_name):
    movie_user_ratings=moviemat[movie_name]
    similar_to_movie=moviemat.corrwith(movie_user_ratings)
    corr_movie=pd.DataFrame(similar_to_movie,columns=['correlation'])
    corr_movie.dropna(inplace=True)
    corr_movie=corr_movie.join(ratings['Number of Ratings'])
    predictions=corr_movie[corr_movie['Number of Ratings']>100].sort_values('correlation',ascending=False)
    return predictions

# %%
a=predict_movies('Titanic (1997)')

# %%
a
# Out:
#                                   correlation  Number of Ratings
# title
# Titanic (1997)                       1.000000                350
# River Wild, The (1994)               0.497600                146
# Abyss, The (1989)                    0.472103                151
# Bram Stoker's Dracula (1992)         0.443560                120
# True Lies (1994)                     0.435104                208
# ...                                       ...                ...
# Raging Bull (1980)                  -0.223660                116
# Jackie Brown (1997)                 -0.236841                126
# Brazil (1985)                       -0.243532                208
# Cold Comfort Farm (1995)            -0.307150                125
# James and the Giant Peach (1996)    -0.370248                126
#
# [334 rows x 2 columns]
